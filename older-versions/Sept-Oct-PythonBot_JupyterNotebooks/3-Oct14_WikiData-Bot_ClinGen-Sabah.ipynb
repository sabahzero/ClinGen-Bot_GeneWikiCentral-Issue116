# %% [markdown]
# # Example bot to replicate the statement added to Wikidata
# Note that these sections are created using the 'Markdown' dropdown option whereas the others are created using 'Code'

# %% [markdown]
# ### Load the relevant modules and packages

# %%
# Script contributions (in order): Sabah Ul-Hasan, Andra Waagmeester, Andrew Su

# Installations by shell (! command)
# pip installations needed based on environment used
# If ran in PyCharm, for example, then directly import (vs needed for notebook, colab, and jenkins)
# Bot will be run in jenkins: http://jenkins.sulab.org/

# !pip install --upgrade pip # Install pip, then ensure it's up-to-date for installing python packages 
# !pip3 install tqdm # Library to visualize installation progress (progress bar)
# !pip3 install termcolor # Module to call on color-coding for the printed output
# !pip3 install wikidataintegrator # Module for wikidata

# Brief terminology overview
# Library or Package: A collection of modules
# Module: File that contains python functions and global variables
# Out:
# Collecting pip
#   Downloading https://files.pythonhosted.org/packages/00/b6/9cfa56b4081ad13874b0c6f96af8ce16cfbc1cb06bedf8e9164ce5551ec1/pip-19.3.1-py2.py3-none-any.whl (1.4MB)
#     100% |████████████████████████████████| 1.4MB 318kB/s eta 0:00:01
# Installing collected packages: pip
#   Found existing installation: pip 9.0.1
#     Uninstalling pip-9.0.1:
#       Successfully uninstalled pip-9.0.1
# Successfully installed pip-19.3.1
# Collecting tqdm
#   Using cached https://files.pythonhosted.org/packages/e1/c1/bc1dba38b48f4ae3c4428aea669c5e27bd5a7642a74c8348451e0bd8ff86/tqdm-4.36.1-py2.py3-none-any.whl
# Installing collected packages: tqdm
# Successfully installed tqdm-4.36.1
# Collecting termcolor
#   Using cached https://files.pythonhosted.org/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz
# Installing collected packages: termcolor
#     Running setup.py install for termcolor ... done
# Successfully installed termcolor-1.1.0
# Collecting wikidataintegrator
#   Using cached https://files.pythonhosted.org/packages/a4/4a/bfac10031ee728718826e265abe2c8211ccf3b543a3e7cc904bf9d5398ef/wikidataintegrator-0.4.2.tar.gz
# Collecting ShExJSG
#   Using cached https://files.pythonhosted.org/packages/9f/f1/91c395b99a613d360b07c94475b52b6ca6779ab53332e2a6df5bb79f8c08/ShExJSG-0.6.8-py2.py3-none-any.whl
# Collecting jsonasobj
#   Using cached https://files.pythonhosted.org/packages/0a/a0/f9951b7ce18718282a00b302f469d6638b25e650783ea416c946355daa3f/jsonasobj-1.2.1.tar.gz
# Requirement already satisfied: mwoauth in /srv/paws/lib/python3.6/site-packages (from wikidataintegrator) (0.3.3)
# Requirement already satisfied: oauthlib in /srv/paws/lib/python3.6/site-packages (from wikidataintegrator) (3.0.1)
# Collecting pyshex
#   Using cached https://files.pythonhosted.org/packages/89/a2/74d4c0ba31ba998f290f723d0b8916faf71ce5edd9b781b29ab2de53cb1a/PyShEx-0.7.12-py3-none-any.whl
# Requirement already satisfied: python-dateutil in /srv/paws/lib/python3.6/site-packages (from wikidataintegrator) (2.8.0)
# Requirement already satisfied: requests in /srv/paws/lib/python3.6/site-packages (from wikidataintegrator) (2.22.0)
# Collecting simplejson
#   Using cached https://files.pythonhosted.org/packages/e3/24/c35fb1c1c315fc0fffe61ea00d3f88e85469004713dab488dee4f35b0aff/simplejson-3.16.0.tar.gz
# Collecting sparql_slurper
#   Using cached https://files.pythonhosted.org/packages/cd/c6/a1a908b2b82b5456719f7b650f770a768d8a1eb2ac40c901aad2f24f2ec1/sparql_slurper-0.2.2-py3-none-any.whl
# Collecting pyshexc>=0.5.4
#   Using cached https://files.pythonhosted.org/packages/15/77/4d948f70b5a36d133603e779be03cce1ecb4be156e9b174d52e67d9f8212/PyShExC-0.7.0-py2.py3-none-any.whl
# Collecting pyjsg>=0.9.0
#   Using cached https://files.pythonhosted.org/packages/6d/95/3e831de9f7108ad962a070b35d6e7b9017e15ea3fdcbe265d59a5a8e1140/PyJSG-0.9.1-py3-none-any.whl
# Requirement already satisfied: requests-oauthlib in /srv/paws/lib/python3.6/site-packages (from mwoauth->wikidataintegrator) (1.2.0)
# Requirement already satisfied: six in /srv/paws/lib/python3.6/site-packages (from mwoauth->wikidataintegrator) (1.12.0)
# Requirement already satisfied: PyJWT<2.0.0,>=1.0.1 in /srv/paws/lib/python3.6/site-packages (from mwoauth->wikidataintegrator) (1.7.1)
# Collecting rdflib-jsonld>=0.4.0
#   Using cached https://files.pythonhosted.org/packages/ba/48/edaad22fc9de34500699f0c7fc9124385dd425fd18857244f126a6f7df66/rdflib-jsonld-0.4.0.tar.gz
# Requirement already satisfied: urllib3 in /srv/paws/lib/python3.6/site-packages (from pyshex->wikidataintegrator) (1.25.2)
# Collecting cfgraph>=0.2.1
#   Using cached https://files.pythonhosted.org/packages/cb/51/3e7e021920cfe2f7d18b672642e13f7dc4f53545d530b52ee6533b6681ca/CFGraph-0.2.1.tar.gz
# Collecting rdflib>=4.2.2
#   Using cached https://files.pythonhosted.org/packages/3c/fe/630bacb652680f6d481b9febbb3e2c3869194a1a5fc3401a4a41195a2f8f/rdflib-4.2.2-py3-none-any.whl
# Collecting sparqlwrapper
#   Using cached https://files.pythonhosted.org/packages/b0/1d/d7c60a451a255fca655fe37eb3f6e3b3daa7d33fc87eeec0d8631d501e76/SPARQLWrapper-1.8.4-py3-none-any.whl
# Requirement already satisfied: certifi>=2017.4.17 in /srv/paws/lib/python3.6/site-packages (from requests->wikidataintegrator) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /srv/paws/lib/python3.6/site-packages (from requests->wikidataintegrator) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /srv/paws/lib/python3.6/site-packages (from requests->wikidataintegrator) (2.8)
# Collecting antlr4-python3-runtime>=4.7
#   Using cached https://files.pythonhosted.org/packages/29/14/8ac135ec7cc9db3f768e2d032776718c6b23f74e63543f0974b4873500b2/antlr4-python3-runtime-4.7.2.tar.gz
# Requirement already satisfied: pyparsing in /srv/paws/lib/python3.6/site-packages (from rdflib>=4.2.2->pyshex->wikidataintegrator) (2.4.0)
# Collecting isodate
#   Using cached https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl
# Installing collected packages: jsonasobj, antlr4-python3-runtime, pyjsg, isodate, rdflib, rdflib-jsonld, pyshexc, ShExJSG, sparqlwrapper, sparql-slurper, cfgraph, pyshex, simplejson, wikidataintegrator
#     Running setup.py install for jsonasobj ... done
#     Running setup.py install for antlr4-python3-runtime ... done
#     Running setup.py install for rdflib-jsonld ... done
#     Running setup.py install for cfgraph ... done
#     Running setup.py install for simplejson ... done
#     Running setup.py install for wikidataintegrator ... done
# Successfully installed ShExJSG-0.6.8 antlr4-python3-runtime-4.7.2 cfgraph-0.2.1 isodate-0.6.0 jsonasobj-1.2.1 pyjsg-0.9.1 pyshex-0.7.12 pyshexc-0.7.0 rdflib-4.2.2 rdflib-jsonld-0.4.0 simplejson-3.16.0 sparql-slurper-0.2.2 sparqlwrapper-1.8.4 wikidataintegrator-0.4.2

# %%
from wikidataintegrator import wdi_core, wdi_login # Imports core and login packages from wikidataintegrator module
from wikidataintegrator.ref_handlers import update_retrieved_if_new_multiple_refs # For retrieving references
from datetime import datetime # For identifying the current date and time
import copy # Copies references needed in the .csv for uploading to wikidata

import pandas as pd # Pandas is a data organization package, then abbreviated to pd
import numpy as np # NumPy is another general purpose package
from termcolor import colored # Imports colored package from termcolor

import os # OS package ensures interaction between the modules (ie WDI) and current operating system is being used

# %% [markdown]
# ### Upload the ClinGen data (source:  https://search.clinicalgenome.org/kb/gene-validity.csv)
# Issue posted on Github: https://github.com/SuLab/GeneWikiCentral/issues/116

# %%
# Set data frame, skip first 6 rows to avoid error
df = pd.read_csv('https://search.clinicalgenome.org/kb/gene-validity.csv', skiprows=6, header=None)   
# pandas is the library with function read.csv -> relabeled as pd to abbreviate

# Input current date and time of file download as a string for ref function later
timeStringNow = datetime.now().strftime("+%Y-%m-%dT00:00:00Z") # String that represents a time (put it as 'midnight')

# Relabel column headings (variables)
df.columns = ['Gene', 'HGNC Gene ID', 'Disease', 'MONDO Disease ID','SOP','Classification','Report Reference URL','Report Date']
# Diseases with similar names but separate MONDO IDs are unique diseases. Enter as unique values within the 'gene association' statement accordingly
# Diseases with the same MONDO IDs associated to the same gene, but with multiple reports should be entered as multiple references
# There are complications with 'Classifications' and associated URLs for which there are mutliple references possible => See ClinGenBot_Status-Output...csv

# View dataframe
df
# Out:
#        Gene HGNC Gene ID                                            Disease  \
# 0     A2ML1   HGNC:23336           Noonan syndrome with multiple lentigines
# 1     A2ML1   HGNC:23336                      cardiofaciocutaneous syndrome
# 2     A2ML1   HGNC:23336                                  Costello syndrome
# 3     A2ML1   HGNC:23336                                    Noonan syndrome
# 4     A2ML1   HGNC:23336  Noonan syndrome-like disorder with loose anage...
# 5      AARS      HGNC:20  undetermined early-onset epileptic encephalopathy
# 6     ABCC9      HGNC:60    hypertrichotic osteochondrodysplasia Cantu type
# 7     ABCD1      HGNC:61             X-linked cerebral adrenoleukodystrophy
# 8    ABHD12   HGNC:15868                                     PHARC syndrome
# 9     ACAD8      HGNC:87            isobutyryl-CoA dehydrogenase deficiency
# 10    ACAD9   HGNC:21497                acyl-CoA dehydrogenase 9 deficiency
# 11    ACADL      HGNC:88       long chain acyl-CoA dehydrogenase deficiency
# 12    ACADM      HGNC:89     medium chain acyl-CoA dehydrogenase deficiency
# 13    ACADS      HGNC:90      short chain acyl-CoA dehydrogenase deficiency
# 14   ACADSB      HGNC:91       2-methylbutyryl-CoA dehydrogenase deficiency
# 15   ACADVL      HGNC:92  very long chain acyl-CoA dehydrogenase deficiency
# 16    ACAT1      HGNC:93                       beta-ketothiolase deficiency
# 17    ACSL4    HGNC:3571     non-syndromic X-linked intellectual disability
# 18    ACTA1     HGNC:129                        hypertrophic cardiomyopathy
# 19    ACTA2     HGNC:130  familial thoracic aortic aneurysm and aortic d...
# 20    ACTC1     HGNC:143                        hypertrophic cardiomyopathy
# 21    ACTG1     HGNC:144                      nonsyndromic genetic deafness
# 22    ACTG1     HGNC:144                        Baraitser-winter syndrome 2
# 23    ACTN2     HGNC:164                           intrinsic cardiomyopathy
# 24   ACVRL1     HGNC:175     telangiectasia, hereditary hemorrhagic, type 2
# 25    ADCY1     HGNC:232          autosomal recessive nonsyndromic deafness
# 26   ADGRV1   HGNC:17416                             Usher syndrome type 2C
# 27   ADGRV1   HGNC:17416                      nonsyndromic genetic deafness
# 28     AFF2    HGNC:3776                      FRAXE intellectual disability
# 29     AGPS     HGNC:327               rhizomelic chondrodysplasia punctata
# ..      ...          ...                                                ...
# 784   UBE2A   HGNC:12472  syndromic X-linked intellectual disability Nas...
# 785   UBE3A   HGNC:12496                                  Angelman syndrome
# 786   UPF3B   HGNC:20439                complex neurodevelopmental disorder
# 787   UQCRQ   HGNC:29594                                     Leigh syndrome
# 788   USH1C   HGNC:12597                              Usher syndrome type 1
# 789   USH1C   HGNC:12597                      nonsyndromic genetic deafness
# 790   USH1G   HGNC:16356                              Usher syndrome type 1
# 791   USH1G   HGNC:16356                      nonsyndromic genetic deafness
# 792   USH2A   HGNC:12601                              Usher syndrome type 2
# 793     VCL   HGNC:12665                        hypertrophic cardiomyopathy
# 794     VHL   HGNC:12687          hereditary pheochromocytoma-paraganglioma
# 795  VPS13B    HGNC:2183                                     Cohen syndrome
# 796    VPS8   HGNC:29122                 arthrogryposis multiplex congenita
# 797     WAS   HGNC:12731                           Wiskott-Aldrich syndrome
# 798    WBP2   HGNC:12738          autosomal recessive nonsyndromic deafness
# 799   WDR45   HGNC:28912                complex neurodevelopmental disorder
# 800    WFS1   HGNC:12762                                   Wolfram syndrome
# 801    WFS1   HGNC:12762                              Wolfram-like syndrome
# 802    WHRN   HGNC:16361                             Usher syndrome type 2D
# 803    WHRN   HGNC:16361                      nonsyndromic genetic deafness
# 804  WRAP53   HGNC:25522                             dyskeratosis congenita
# 805     WRN   HGNC:12791                                    Werner syndrome
# 806     XPA   HGNC:12814                      xeroderma pigmentosum group A
# 807     XPC   HGNC:12816                      xeroderma pigmentosum group C
# 808   XRCC2   HGNC:12829                        hereditary breast carcinoma
# 809   XRCC2   HGNC:12829                            familial ovarian cancer
# 810   XRCC4   HGNC:12831               hereditary nonpolyposis colon cancer
# 811    ZEB2   HGNC:14881                              Mowat-Wilson syndrome
# 812  ZNF292   HGNC:18410                complex neurodevelopmental disorder
# 813   ZNF81   HGNC:13156     non-syndromic X-linked intellectual disability
#
#     MONDO Disease ID   SOP        Classification  \
# 0      MONDO_0007893  SOP5  No Reported Evidence
# 1      MONDO_0015280  SOP5  No Reported Evidence
# 2      MONDO_0009026  SOP5  No Reported Evidence
# 3      MONDO_0018997  SOP5              Disputed
# 4      MONDO_0011899  SOP5  No Reported Evidence
# 5      MONDO_0018614  SOP6               Limited
# 6      MONDO_0009406  SOP4            Definitive
# 7      MONDO_0010247  SOP4            Definitive
# 8      MONDO_0012984  SOP5            Definitive
# 9      MONDO_0012648  SOP6            Definitive
# 10     MONDO_0012624  SOP6            Definitive
# 11     MONDO_0020531  SOP6              Disputed
# 12     MONDO_0008721  SOP6            Definitive
# 13     MONDO_0008722  SOP6            Definitive
# 14     MONDO_0012392  SOP6            Definitive
# 15     MONDO_0008723  SOP6            Definitive
# 16     MONDO_0008760  SOP6            Definitive
# 17     MONDO_0019181  SOP4              Moderate
# 18     MONDO_0005045  SOP4  No Reported Evidence
# 19     MONDO_0019625  SOP4            Definitive
# 20     MONDO_0005045  SOP4            Definitive
# 21     MONDO_0019497  SOP6            Definitive
# 22     MONDO_0013812  SOP6            Definitive
# 23     MONDO_0000591  SOP5              Moderate
# 24     MONDO_0010880  SOP6            Definitive
# 25     MONDO_0019588  SOP4               Limited
# 26     MONDO_0011558  SOP4            Definitive
# 27     MONDO_0019497  SOP6              Disputed
# 28     MONDO_0010659  SOP4            Definitive
# 29     MONDO_0015776  SOP6            Definitive
# ..               ...   ...                   ...
# 784    MONDO_0010461  SOP5            Definitive
# 785    MONDO_0007113  SOP5            Definitive
# 786    MONDO_0100038  SOP6            Definitive
# 787    MONDO_0009723  SOP6               Limited
# 788    MONDO_0010168  SOP4            Definitive
# 789    MONDO_0019497  SOP6               Limited
# 790    MONDO_0010168  SOP4            Definitive
# 791    MONDO_0019497  SOP6              Disputed
# 792    MONDO_0016484  SOP4            Definitive
# 793    MONDO_0005045  SOP4               Limited
# 794    MONDO_0017366  SOP4            Definitive
# 795    MONDO_0008999  SOP6            Definitive
# 796    MONDO_0015168  SOP4               Limited
# 797    MONDO_0010518  SOP6            Definitive
# 798    MONDO_0019588  SOP6               Limited
# 799    MONDO_0100038  SOP6            Definitive
# 800    MONDO_0018105  SOP5            Definitive
# 801    MONDO_0013673  SOP6            Definitive
# 802    MONDO_0012662  SOP4            Definitive
# 803    MONDO_0019497  SOP6              Moderate
# 804    MONDO_0015780  SOP4              Moderate
# 805    MONDO_0010196  SOP6            Definitive
# 806    MONDO_0010210  SOP6            Definitive
# 807    MONDO_0010211  SOP6            Definitive
# 808    MONDO_0016419  SOP4               Limited
# 809    MONDO_0016248  SOP4  No Reported Evidence
# 810    MONDO_0018630  SOP4               Limited
# 811    MONDO_0009341  SOP5            Definitive
# 812    MONDO_0100038  SOP6               Limited
# 813    MONDO_0019181  SOP5              Disputed
#
#                                   Report Reference URL  \
# 0    https://search.clinicalgenome.org/kb/gene-vali...
# 1    https://search.clinicalgenome.org/kb/gene-vali...
# 2    https://search.clinicalgenome.org/kb/gene-vali...
# 3    https://search.clinicalgenome.org/kb/gene-vali...
# 4    https://search.clinicalgenome.org/kb/gene-vali...
# 5    https://search.clinicalgenome.org/kb/gene-vali...
# 6    https://search.clinicalgenome.org/kb/gene-vali...
# 7    https://search.clinicalgenome.org/kb/gene-vali...
# 8    https://search.clinicalgenome.org/kb/gene-vali...
# 9    https://search.clinicalgenome.org/kb/gene-vali...
# 10   https://search.clinicalgenome.org/kb/gene-vali...
# 11   https://search.clinicalgenome.org/kb/gene-vali...
# 12   https://search.clinicalgenome.org/kb/gene-vali...
# 13   https://search.clinicalgenome.org/kb/gene-vali...
# 14   https://search.clinicalgenome.org/kb/gene-vali...
# 15   https://search.clinicalgenome.org/kb/gene-vali...
# 16   https://search.clinicalgenome.org/kb/gene-vali...
# 17   https://search.clinicalgenome.org/kb/gene-vali...
# 18   https://search.clinicalgenome.org/kb/gene-vali...
# 19   https://search.clinicalgenome.org/kb/gene-vali...
# 20   https://search.clinicalgenome.org/kb/gene-vali...
# 21   https://search.clinicalgenome.org/kb/gene-vali...
# 22   https://search.clinicalgenome.org/kb/gene-vali...
# 23   https://search.clinicalgenome.org/kb/gene-vali...
# 24   https://search.clinicalgenome.org/kb/gene-vali...
# 25   https://search.clinicalgenome.org/kb/gene-vali...
# 26   https://search.clinicalgenome.org/kb/gene-vali...
# 27   https://search.clinicalgenome.org/kb/gene-vali...
# 28   https://search.clinicalgenome.org/kb/gene-vali...
# 29   https://search.clinicalgenome.org/kb/gene-vali...
# ..                                                 ...
# 784  https://search.clinicalgenome.org/kb/gene-vali...
# 785  https://search.clinicalgenome.org/kb/gene-vali...
# 786  https://search.clinicalgenome.org/kb/gene-vali...
# 787  https://search.clinicalgenome.org/kb/gene-vali...
# 788  https://search.clinicalgenome.org/kb/gene-vali...
# 789  https://search.clinicalgenome.org/kb/gene-vali...
# 790  https://search.clinicalgenome.org/kb/gene-vali...
# 791  https://search.clinicalgenome.org/kb/gene-vali...
# 792  https://search.clinicalgenome.org/kb/gene-vali...
# 793  https://search.clinicalgenome.org/kb/gene-vali...
# 794  https://search.clinicalgenome.org/kb/gene-vali...
# 795  https://search.clinicalgenome.org/kb/gene-vali...
# 796  https://search.clinicalgenome.org/kb/gene-vali...
# 797  https://search.clinicalgenome.org/kb/gene-vali...
# 798  https://search.clinicalgenome.org/kb/gene-vali...
# 799  https://search.clinicalgenome.org/kb/gene-vali...
# 800  https://search.clinicalgenome.org/kb/gene-vali...
# 801  https://search.clinicalgenome.org/kb/gene-vali...
# 802  https://search.clinicalgenome.org/kb/gene-vali...
# 803  https://search.clinicalgenome.org/kb/gene-vali...
# 804  https://search.clinicalgenome.org/kb/gene-vali...
# 805  https://search.clinicalgenome.org/kb/gene-vali...
# 806  https://search.clinicalgenome.org/kb/gene-vali...
# 807  https://search.clinicalgenome.org/kb/gene-vali...
# 808  https://search.clinicalgenome.org/kb/gene-vali...
# 809  https://search.clinicalgenome.org/kb/gene-vali...
# 810  https://search.clinicalgenome.org/kb/gene-vali...
# 811  https://search.clinicalgenome.org/kb/gene-vali...
# 812  https://search.clinicalgenome.org/kb/gene-vali...
# 813  https://search.clinicalgenome.org/kb/gene-vali...
#
#                   Report Date
# 0    2018-06-07T14:37:47.175Z
# 1    2018-06-07T14:31:03.696Z
# 2    2018-06-07T14:34:05.324Z
# 3    2018-06-07T14:23:53.157Z
# 4    2018-06-07T14:40:11.599Z
# 5    2018-11-20T17:00:00.000Z
# 6         2017-09-27T00:00:00
# 7         2018-02-07T14:00:00
# 8    2018-06-28T16:45:15.791Z
# 9    2019-04-26T16:00:00.000Z
# 10   2018-03-27T16:00:00.000Z
# 11   2018-09-25T16:00:00.000Z
# 12   2018-01-23T17:00:00.000Z
# 13   2018-01-23T17:00:00.000Z
# 14   2019-03-22T16:00:00.000Z
# 15   2018-02-20T17:00:00.000Z
# 16   2018-05-22T16:00:00.000Z
# 17        2017-10-20T00:00:00
# 18                      false
# 19        2016-09-27T00:00:00
# 20        2017-10-23T14:00:00
# 21   2019-01-07T17:00:00.000Z
# 22   2019-01-07T17:00:00.000Z
# 23   2018-08-06T13:12:55.615Z
# 24   2019-08-28T16:00:00.000Z
# 25        2017-05-10T00:00:00
# 26        2017-02-15T00:00:00
# 27   2019-03-19T16:00:00.000Z
# 28        2017-10-20T00:00:00
# 29   2019-10-04T20:27:42.154Z
# ..                        ...
# 784  2018-07-13T13:49:34.109Z
# 785  2018-05-02T13:23:44.716Z
# 786  2019-07-03T20:14:44.825Z
# 787  2019-10-16T14:46:56.909Z
# 788       2017-02-15T00:00:00
# 789  2018-06-11T04:00:00.000Z
# 790       2017-02-15T00:00:00
# 791  2019-05-21T16:00:00.000Z
# 792       2017-02-15T00:00:00
# 793       2017-06-01T00:00:00
# 794       2017-06-16T00:00:00
# 795  2018-11-13T15:34:57.342Z
# 796       2016-11-24T00:00:00
# 797  2018-10-12T20:54:25.459Z
# 798  2018-12-09T17:00:00.000Z
# 799  2019-06-18T18:00:00.000Z
# 800  2018-09-11T18:54:09.174Z
# 801  2018-04-17T04:00:00.000Z
# 802       2017-05-10T00:00:00
# 803  2018-12-26T17:00:00.000Z
# 804       2017-01-25T00:00:00
# 805  2018-10-09T17:00:00.000Z
# 806  2018-11-02T21:36:51.734Z
# 807  2018-11-02T21:42:21.860Z
# 808       2017-05-10T00:00:00
# 809       2017-04-26T00:00:00
# 810       2017-05-08T00:00:00
# 811  2018-05-24T12:34:43.951Z
# 812  2019-01-15T17:00:00.000Z
# 813  2018-06-28T18:56:10.060Z
#
# [814 rows x 8 columns]

# %% [markdown]
# If we do isoformat, it doesnt like it.
#
# WDApiError: {'error': {'code': 'modification-failed', 'info': 'Data value corrupt: $timestamp must resemble ISO 8601, given 2019-10-18T16:32:34.420821', 'messages': [{'name': 'wikibase-validator-bad-value', 'parameters': ['$timestamp must resemble ISO 8601, given 2019-10-18T16:32:34.420821'], 'html': {'*': 'Data value corrupt: $timestamp must resemble ISO 8601, given 2019-10-18T16:32:34.420821'}}], '*': 'See https://www.wikidata.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}, 'servedby': 'mw1347'}

# %% [markdown]
# ### Delete section after automated
# #### Adjust ClinGen data file for practice run before implementing all entries
# Include a row that has already been entered: Row 1 <br/>
# Include a row that hasn't yet been entered: Row 0
#
# ### Delete section after automated

# %%
subsetdf = df[15:30] # Subset for first two rows of the df and rename it as subsetdf
subsetdf
# Out:
#       Gene HGNC Gene ID                                            Disease  \
# 15  ACADVL      HGNC:92  very long chain acyl-CoA dehydrogenase deficiency
# 16   ACAT1      HGNC:93                       beta-ketothiolase deficiency
# 17   ACSL4    HGNC:3571     non-syndromic X-linked intellectual disability
# 18   ACTA1     HGNC:129                        hypertrophic cardiomyopathy
# 19   ACTA2     HGNC:130  familial thoracic aortic aneurysm and aortic d...
# 20   ACTC1     HGNC:143                        hypertrophic cardiomyopathy
# 21   ACTG1     HGNC:144                      nonsyndromic genetic deafness
# 22   ACTG1     HGNC:144                        Baraitser-winter syndrome 2
# 23   ACTN2     HGNC:164                           intrinsic cardiomyopathy
# 24  ACVRL1     HGNC:175     telangiectasia, hereditary hemorrhagic, type 2
# 25   ADCY1     HGNC:232          autosomal recessive nonsyndromic deafness
# 26  ADGRV1   HGNC:17416                             Usher syndrome type 2C
# 27  ADGRV1   HGNC:17416                      nonsyndromic genetic deafness
# 28    AFF2    HGNC:3776                      FRAXE intellectual disability
# 29    AGPS     HGNC:327               rhizomelic chondrodysplasia punctata
#
#    MONDO Disease ID   SOP        Classification  \
# 15    MONDO_0008723  SOP6            Definitive
# 16    MONDO_0008760  SOP6            Definitive
# 17    MONDO_0019181  SOP4              Moderate
# 18    MONDO_0005045  SOP4  No Reported Evidence
# 19    MONDO_0019625  SOP4            Definitive
# 20    MONDO_0005045  SOP4            Definitive
# 21    MONDO_0019497  SOP6            Definitive
# 22    MONDO_0013812  SOP6            Definitive
# 23    MONDO_0000591  SOP5              Moderate
# 24    MONDO_0010880  SOP6            Definitive
# 25    MONDO_0019588  SOP4               Limited
# 26    MONDO_0011558  SOP4            Definitive
# 27    MONDO_0019497  SOP6              Disputed
# 28    MONDO_0010659  SOP4            Definitive
# 29    MONDO_0015776  SOP6            Definitive
#
#                                  Report Reference URL  \
# 15  https://search.clinicalgenome.org/kb/gene-vali...
# 16  https://search.clinicalgenome.org/kb/gene-vali...
# 17  https://search.clinicalgenome.org/kb/gene-vali...
# 18  https://search.clinicalgenome.org/kb/gene-vali...
# 19  https://search.clinicalgenome.org/kb/gene-vali...
# 20  https://search.clinicalgenome.org/kb/gene-vali...
# 21  https://search.clinicalgenome.org/kb/gene-vali...
# 22  https://search.clinicalgenome.org/kb/gene-vali...
# 23  https://search.clinicalgenome.org/kb/gene-vali...
# 24  https://search.clinicalgenome.org/kb/gene-vali...
# 25  https://search.clinicalgenome.org/kb/gene-vali...
# 26  https://search.clinicalgenome.org/kb/gene-vali...
# 27  https://search.clinicalgenome.org/kb/gene-vali...
# 28  https://search.clinicalgenome.org/kb/gene-vali...
# 29  https://search.clinicalgenome.org/kb/gene-vali...
#
#                  Report Date
# 15  2018-02-20T17:00:00.000Z
# 16  2018-05-22T16:00:00.000Z
# 17       2017-10-20T00:00:00
# 18                     false
# 19       2016-09-27T00:00:00
# 20       2017-10-23T14:00:00
# 21  2019-01-07T17:00:00.000Z
# 22  2019-01-07T17:00:00.000Z
# 23  2018-08-06T13:12:55.615Z
# 24  2019-08-28T16:00:00.000Z
# 25       2017-05-10T00:00:00
# 26       2017-02-15T00:00:00
# 27  2019-03-19T16:00:00.000Z
# 28       2017-10-20T00:00:00
# 29  2019-10-04T20:27:42.154Z

# %% [markdown]
# ### Log into Wikidata for executing the task

# %%
print("Logging in...") # Outputs 'Logging in' as you wait to have your username and password recognized

# Enter your own username and password ** to be updated to ProteinBoxBot
os.environ["WDUSER"] = "username" # Uses os package to call and set the environment for wikidata username
os.environ["WDPASS"] = "password"

# If else conditional for both username and password being in the local environment
if "WDUSER" in os.environ and "WDPASS" in os.environ: 
    WDUSER = os.environ['WDUSER']
    WDPASS = os.environ['WDPASS']
else: # Else statement outputs error command if not in the local python environment
    raise ValueError("WDUSER and WDPASS must be specified in local.py or as environment variables")
    
login = wdi_login.WDLogin(WDUSER, WDPASS) # wdi_login package calls upon login function with atributed username and password and sets as 'login'
# Out:
# Logging in...
# https://www.wikidata.org/w/api.php
# Successfully logged in as Sulhasan

# %% [markdown]
# ### For loop that iterates across dataframe and uploads to WikiData

# %%
# Create a function for adding references to then be iterated in the loop
def create_reference(): # Function defined as 'create_reference()'
        refStatedIn = wdi_core.WDItemID(value="Q64403342", prop_nr="P248", is_reference=True) # Q64403342 is the ClinGen item Q# and P248 is 'stated in' property P#
        refRetrieved = wdi_core.WDTime(timeStringNow, prop_nr="P813", is_reference=True) # calls on previous string with time stamp from file download, P813 is 'retrieved'
        refURL = wdi_core.WDUrl((subsetdf.loc[index, 'Report Reference URL']), prop_nr="P854", is_reference=True) # P854 is 'reference URL'
        return [refStatedIn, refRetrieved, refURL]

# %%
subsetdf['Status'] = "pending" # Create "Status" column with 'pending' for all cells ('error' or 'complete' or 'previously logged' downstream)
subsetdf['Definitive'] = "" # Empty cell to be replaced with 'yes' or 'no' string
subsetdf['Gene QID'] = "" # To be replaced with 'absent' or 'multiple'
subsetdf['Disease QID'] = "" # To be replaced with 'absent' or 'multiple'

subsetdf
# Python output shows concern that we're entering the same string for all cells, but that's what we want so it's fine
# Out:
# /srv/paws/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /srv/paws/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /srv/paws/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /srv/paws/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#       Gene HGNC Gene ID                                            Disease  \
# 15  ACADVL      HGNC:92  very long chain acyl-CoA dehydrogenase deficiency
# 16   ACAT1      HGNC:93                       beta-ketothiolase deficiency
# 17   ACSL4    HGNC:3571     non-syndromic X-linked intellectual disability
# 18   ACTA1     HGNC:129                        hypertrophic cardiomyopathy
# 19   ACTA2     HGNC:130  familial thoracic aortic aneurysm and aortic d...
# 20   ACTC1     HGNC:143                        hypertrophic cardiomyopathy
# 21   ACTG1     HGNC:144                      nonsyndromic genetic deafness
# 22   ACTG1     HGNC:144                        Baraitser-winter syndrome 2
# 23   ACTN2     HGNC:164                           intrinsic cardiomyopathy
# 24  ACVRL1     HGNC:175     telangiectasia, hereditary hemorrhagic, type 2
# 25   ADCY1     HGNC:232          autosomal recessive nonsyndromic deafness
# 26  ADGRV1   HGNC:17416                             Usher syndrome type 2C
# 27  ADGRV1   HGNC:17416                      nonsyndromic genetic deafness
# 28    AFF2    HGNC:3776                      FRAXE intellectual disability
# 29    AGPS     HGNC:327               rhizomelic chondrodysplasia punctata
#
#    MONDO Disease ID   SOP        Classification  \
# 15    MONDO_0008723  SOP6            Definitive
# 16    MONDO_0008760  SOP6            Definitive
# 17    MONDO_0019181  SOP4              Moderate
# 18    MONDO_0005045  SOP4  No Reported Evidence
# 19    MONDO_0019625  SOP4            Definitive
# 20    MONDO_0005045  SOP4            Definitive
# 21    MONDO_0019497  SOP6            Definitive
# 22    MONDO_0013812  SOP6            Definitive
# 23    MONDO_0000591  SOP5              Moderate
# 24    MONDO_0010880  SOP6            Definitive
# 25    MONDO_0019588  SOP4               Limited
# 26    MONDO_0011558  SOP4            Definitive
# 27    MONDO_0019497  SOP6              Disputed
# 28    MONDO_0010659  SOP4            Definitive
# 29    MONDO_0015776  SOP6            Definitive
#
#                                  Report Reference URL  \
# 15  https://search.clinicalgenome.org/kb/gene-vali...
# 16  https://search.clinicalgenome.org/kb/gene-vali...
# 17  https://search.clinicalgenome.org/kb/gene-vali...
# 18  https://search.clinicalgenome.org/kb/gene-vali...
# 19  https://search.clinicalgenome.org/kb/gene-vali...
# 20  https://search.clinicalgenome.org/kb/gene-vali...
# 21  https://search.clinicalgenome.org/kb/gene-vali...
# 22  https://search.clinicalgenome.org/kb/gene-vali...
# 23  https://search.clinicalgenome.org/kb/gene-vali...
# 24  https://search.clinicalgenome.org/kb/gene-vali...
# 25  https://search.clinicalgenome.org/kb/gene-vali...
# 26  https://search.clinicalgenome.org/kb/gene-vali...
# 27  https://search.clinicalgenome.org/kb/gene-vali...
# 28  https://search.clinicalgenome.org/kb/gene-vali...
# 29  https://search.clinicalgenome.org/kb/gene-vali...
#
#                  Report Date   Status Definitive Gene QID Disease QID
# 15  2018-02-20T17:00:00.000Z  pending
# 16  2018-05-22T16:00:00.000Z  pending
# 17       2017-10-20T00:00:00  pending
# 18                     false  pending
# 19       2016-09-27T00:00:00  pending
# 20       2017-10-23T14:00:00  pending
# 21  2019-01-07T17:00:00.000Z  pending
# 22  2019-01-07T17:00:00.000Z  pending
# 23  2018-08-06T13:12:55.615Z  pending
# 24  2019-08-28T16:00:00.000Z  pending
# 25       2017-05-10T00:00:00  pending
# 26       2017-02-15T00:00:00  pending
# 27  2019-03-19T16:00:00.000Z  pending
# 28       2017-10-20T00:00:00  pending
# 29  2019-10-04T20:27:42.154Z  pending

# %%
# For loop that executes the following through each row of the dataframe 
# index is row number, row is all variables and values for that row
for index, row in subsetdf.iterrows():
    
    # Write for rows only for where the Classification is 'Definitive'
    if row['Classification']!='Definitive': # If the string is anything other than 'Definitive' for the Classification column
        subsetdf.at[index, 'Status'] = "error" # Then input "error" in the Status column
        subsetdf.at[index, 'Definitive'] = "no" # And 'no' for Definitive classification
        continue # And skip the rest of the for loop
    else:
        subsetdf.at[index, 'Definitive'] = "yes" 
        
    # Identifies the string in the Gene or Disease column for a given row
    HGNC = subsetdf.loc[index, 'Gene'] 
    MONDO = subsetdf.loc[index, 'MONDO Disease ID'].replace("_", ":") # .replace() changes _ to : for SparQL query
    
    # SparQL query to search for Gene or Diseasae in Wikidata based on HGNC (P353) or MONDO (P5270)
    sparqlQuery_HGNC = "SELECT * WHERE {?gene wdt:P353 \""+HGNC+"\"}" 
    result_HGNC = wdi_core.WDItemEngine.execute_sparql_query(sparqlQuery_HGNC) # Resultant query
    sparqlQuery_MONDO = "SELECT * WHERE {?disease wdt:P5270 \""+MONDO+"\"}" 
    result_MONDO = wdi_core.WDItemEngine.execute_sparql_query(sparqlQuery_MONDO)
    
    # Conditional that utilizes length function to call upon the result dictionary for either Gene or Disease
    if len(result_HGNC["results"]["bindings"])==1: # We only want one Q# result 
        HGNC_qid = result_HGNC["results"]["bindings"][0]["gene"]["value"].replace("http://www.wikidata.org/entity/", "") 
    elif len(result_HGNC["results"]["bindings"])>1: # If the value is greater than 1 (if the Gene shows up with more than one Q#)
        subsetdf.at[index, 'Status'] = "error" 
        subsetdf.at[index, 'Gene QID'] = "multiple" 
        continue 
    else: # If the value is 0
        subsetdf.at[index, 'Status'] = "error" 
        subsetdf.at[index, 'Gene QID'] = "absent" 
        continue 
        
    # Note that we DONT want to nest, otherwise it will log the disease qid from the previously successful run   
    if len(result_MONDO["results"]["bindings"])==1: 
        MONDO_qid = result_MONDO["results"]["bindings"][0]["disease"]["value"].replace("http://www.wikidata.org/entity/", "") 
    elif len(result_MONDO["results"]["bindings"])>1: 
        subsetdf.at[index, 'Status'] = "error" 
        subsetdf.at[index, 'Disease QID'] = "multiple" 
        continue
    else:
        subsetdf.at[index, 'Status'] = "error" 
        subsetdf.at[index, 'Disease QID'] = "absent" 
        continue
        
    # Call upon create_reference() function created, note that function will to existing references (not overwrite)     
    reference = create_reference() 
 
    # Add disease value to gene item page, and gene value to disease item page

    statement_HGNC = [wdi_core.WDItemID(value=MONDO_qid, prop_nr="P2293", references=[copy.deepcopy(reference)])] # Creates 'gene assocation' statement (P2293) whether or not it's already there, and includes the references
    wikidata_HGNCitem = wdi_core.WDItemEngine(wd_item_id=HGNC_qid,data=statement_HGNC, append_value=["P2293"])
    wikidata_HGNCitem.get_wd_json_representation() # Gives json structure that submitted to API, can be helpful for debugging 
    statement_MONDO = [wdi_core.WDItemID(value=HGNC_qid, prop_nr="P2293", references=[copy.deepcopy(reference)])] # Symmetry for disease item page
    wikidata_MONDOitem = wdi_core.WDItemEngine(wd_item_id=MONDO_qid,data=statement_MONDO, append_value=["P2293"])
    wikidata_MONDOitem.get_wd_json_representation()
    
    subsetdf.at[index, 'Status'] = "complete" 
    print(colored(HGNC,"blue"), "Gene successfully logged as", colored(wikidata_HGNCitem.write(login),"blue"), "and", colored(MONDO,"green"), "Disease successfully logged as", colored(wikidata_MONDOitem.write(login),"green"))

# Write output to a .csv file
now = datetime.now() # Retrieves current time and saves it as 'now'
# Includes hour:minute:second_dd-mm-yyyy time stamp (https://en.wikipedia.org/wiki/ISO_8601)
subsetdf.to_csv("ClinGenBot_Status-Output_" + now.isoformat() + ".csv")  # isoformat
subsetdf

# Brief terminology overview

# Types of data structures (Data Structure: How we store and retrieve data)
# We can easily figure out what type of data structure something with 'print(type())'
# String: A mutable list of characters in order (keystroke, letter, number...)
# List: denoted by [], a changeable/mutable and sequence of objects/elements where each value inside of the element(s) within a list is considera an item
# Tuple: denoted by (), an unchangeable sequence of objects (similar to lists, except with parentheses and cannot be changed)
# Array: Stores values of the same data type, which is its main distinction from a list 
# Dictionary: denoted by {}, maps mutable set of objects referred to as 'keys' to another set referred to as 'values' 
# Set: An unordered collection of data that is mutable with no duplicate elements
# Frozen set: An unmutable set

# Conditionals and loops
# Conditionals: if, if else, chained vs nested 
# Iterations (loops): reassignment, variable update, for vs while
# Out:
# ACADVL Gene successfully logged as Q15996541 and MONDO:0008723 Disease successfully logged as Q7923095
# ACAT1 Gene successfully logged as Q14913201 and MONDO:0008760 Disease successfully logged as Q4897218
# ACTG1 Gene successfully logged as Q17709277 and MONDO:0019497 Disease successfully logged as Q9079046
# ADGRV1 Gene successfully logged as Q18047368 and MONDO:0011558 Disease successfully logged as Q32143643
# AFF2 Gene successfully logged as Q17928899 and MONDO:0010659 Disease successfully logged as Q21051307
#       Gene HGNC Gene ID                                            Disease  \
# 15  ACADVL      HGNC:92  very long chain acyl-CoA dehydrogenase deficiency
# 16   ACAT1      HGNC:93                       beta-ketothiolase deficiency
# 17   ACSL4    HGNC:3571     non-syndromic X-linked intellectual disability
# 18   ACTA1     HGNC:129                        hypertrophic cardiomyopathy
# 19   ACTA2     HGNC:130  familial thoracic aortic aneurysm and aortic d...
# 20   ACTC1     HGNC:143                        hypertrophic cardiomyopathy
# 21   ACTG1     HGNC:144                      nonsyndromic genetic deafness
# 22   ACTG1     HGNC:144                        Baraitser-winter syndrome 2
# 23   ACTN2     HGNC:164                           intrinsic cardiomyopathy
# 24  ACVRL1     HGNC:175     telangiectasia, hereditary hemorrhagic, type 2
# 25   ADCY1     HGNC:232          autosomal recessive nonsyndromic deafness
# 26  ADGRV1   HGNC:17416                             Usher syndrome type 2C
# 27  ADGRV1   HGNC:17416                      nonsyndromic genetic deafness
# 28    AFF2    HGNC:3776                      FRAXE intellectual disability
# 29    AGPS     HGNC:327               rhizomelic chondrodysplasia punctata
#
#    MONDO Disease ID   SOP        Classification  \
# 15    MONDO_0008723  SOP6            Definitive
# 16    MONDO_0008760  SOP6            Definitive
# 17    MONDO_0019181  SOP4              Moderate
# 18    MONDO_0005045  SOP4  No Reported Evidence
# 19    MONDO_0019625  SOP4            Definitive
# 20    MONDO_0005045  SOP4            Definitive
# 21    MONDO_0019497  SOP6            Definitive
# 22    MONDO_0013812  SOP6            Definitive
# 23    MONDO_0000591  SOP5              Moderate
# 24    MONDO_0010880  SOP6            Definitive
# 25    MONDO_0019588  SOP4               Limited
# 26    MONDO_0011558  SOP4            Definitive
# 27    MONDO_0019497  SOP6              Disputed
# 28    MONDO_0010659  SOP4            Definitive
# 29    MONDO_0015776  SOP6            Definitive
#
#                                  Report Reference URL  \
# 15  https://search.clinicalgenome.org/kb/gene-vali...
# 16  https://search.clinicalgenome.org/kb/gene-vali...
# 17  https://search.clinicalgenome.org/kb/gene-vali...
# 18  https://search.clinicalgenome.org/kb/gene-vali...
# 19  https://search.clinicalgenome.org/kb/gene-vali...
# 20  https://search.clinicalgenome.org/kb/gene-vali...
# 21  https://search.clinicalgenome.org/kb/gene-vali...
# 22  https://search.clinicalgenome.org/kb/gene-vali...
# 23  https://search.clinicalgenome.org/kb/gene-vali...
# 24  https://search.clinicalgenome.org/kb/gene-vali...
# 25  https://search.clinicalgenome.org/kb/gene-vali...
# 26  https://search.clinicalgenome.org/kb/gene-vali...
# 27  https://search.clinicalgenome.org/kb/gene-vali...
# 28  https://search.clinicalgenome.org/kb/gene-vali...
# 29  https://search.clinicalgenome.org/kb/gene-vali...
#
#                  Report Date    Status Definitive Gene QID Disease QID
# 15  2018-02-20T17:00:00.000Z  complete        yes
# 16  2018-05-22T16:00:00.000Z  complete        yes
# 17       2017-10-20T00:00:00     error         no
# 18                     false     error         no
# 19       2016-09-27T00:00:00     error        yes               absent
# 20       2017-10-23T14:00:00     error        yes               absent
# 21  2019-01-07T17:00:00.000Z  complete        yes
# 22  2019-01-07T17:00:00.000Z     error        yes               absent
# 23  2018-08-06T13:12:55.615Z     error         no
# 24  2019-08-28T16:00:00.000Z     error        yes               absent
# 25       2017-05-10T00:00:00     error         no
# 26       2017-02-15T00:00:00  complete        yes
# 27  2019-03-19T16:00:00.000Z     error         no
# 28       2017-10-20T00:00:00  complete        yes
# 29  2019-10-04T20:27:42.154Z     error        yes               absent

# %%
strftime("%H:%M:%S_%Y-%m-%d")

# %% [markdown]
# # Troubleshooting SparQL query
#
# # A brand new statement
# # Statement that is ClinGen
# # Statement that isn't ClinGen
# # Create explicit tests (output)
# # ref_handlers (ginger's code) -- handful of commands in wdi
# # No, we don't want to overwrite the statements (assume that the data is always good) *email ClinGen
#
# # if x != reference:
# # write statement
#     # if x != reference (mondo)
#     # write statement
#     # else ...how to do look at both at the same time
# # else:
# # subsetdf.at[index, 'Status'] = "previously logged"
# # continue
#
# # For gene
#
# ```
# SELECT ?gene ?geneLabel ?reference_stated_in ?reference_URL WHERE{
#     VALUES ?gene {HGNC_qid}
#     ?disease p:P2293 ?statement .
#     ?statement ps:P2293 ?MONDO_qid.
#     ?statement prov:wasDerivedFrom/pr:P248 ?reference_stated_in .
#     ?statement prov:wasDerivedFrom/pr:P854 ?reference_URL
#     SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . }
# }
# ```
#
# # For disease
# SELECT ?disease ?diseaseLabel ?reference_stated_in ?reference_URL WHERE{
#     VALUES ?disease {MONDO_qid}
#     ?disease p:P2293 ?statement .
#     ?statement ps:P2293 ?HGNC_qid.
#     ?statement prov:wasDerivedFrom/pr:P248 ?reference_stated_in .
#     ?statement prov:wasDerivedFrom/pr:P854 ?reference_URL
#     SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . }
# }
